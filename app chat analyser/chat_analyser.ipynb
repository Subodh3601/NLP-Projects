# %%
import re
import pandas as pd
import numpy as np

# %%
f = open('/content/WhatsApp Chat with HAPPY family.txt','r',encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 7/29/23, 08:47 - You created group "HAPPY family"
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/5/23, 16:32 - Didi: <Media omitted>
# 9/7/23, 08:35 - Didi: <Media omitted>
# 9/7/23, 08:38 - Didi: <Media omitted>
# 9/7/23, 08:43 - Reshu Bhabhi: 👌🏻👌🏻
# 9/7/23, 08:49 - Mona: Great bhai bahan dono dancer ho gaye
# 9/7/23, 10:24 - Reshu Bhabhi: <Media omitted>
# 9/7/23, 10:25 - Reshu Bhabhi: Shanvi ka b same song hai
# 9/7/23, 10:56 - Anil Jiju: Jai shree krishna 🕉️🙏🙏
# 9/7/23, 11:35 - Bhaiya Jio: 👏👏👏👏
# 9/7/23, 11:35 - Bhaiya Jio: 👏👏👏👏
# 9/7/23, 12:28 - Mona: Shanvi ke liye v clapping👏👏👏
# 9/8/23, 07:48 - Mona: Happy birthday bhabhi 🥳🥳🥳
# 9/8/23, 08:42 - Didi: Wish u a very happy birthday dear bhabhi 🎂🎂🎂🎂🎂🍬🍬🍫🍫🍫🌹🌹🌹
# 9/8/23, 12:38 - Reshu Bhabhi: Thankyou mona 🙏🏻
# 9/8/23, 12:38 - Reshu Bhabhi: This message was deleted
# 9/8/23, 12:39 - Bade Jiju: Happy Birthday bhabhiji 🎂🎂
# 9/8/23, 12:39 - Reshu Bhabhi: Thankyou jijaji 🙏🏻
# 9/8/23, 12:40 - Mona: Bhabhi typing mistake 🤪
# 9/8/23, 12:41 - Reshu Bhabhi: 😄😄
# 9/8/23, 12:41 - Reshu Bhabhi: Thankyou didi 🙏🏻🙏🏻😄
# 9/8/23, 17:20 - Anil Jiju: <Media omitted>
# 9/8/23, 17:21 - Anil Jiju: Happy birthday 🎂🎂 🎈 Bhabhi ji.. enjoy your special day with lots of love and blessings.
# 9/8/23, 19:11 - Reshu Bhabhi: Thankyou jijaji 🙏🏻
# 10/7/23, 10:07 - Reshu Bhabhi: https://wintermedieval.top/nTiwpTTTT56d?xxyl1696653395155
# 10/7/23, 11:13 - Mona: https://thirteensquad.top/nTiwpTTTT218?ueuz1696657410648
# 10/7/23, 11:29 - Mona: It's a scam yaar
# 10/7/23, 11:30 - Mona: Sbko send kr diya socha tata hai sayad sahi ho bt ye v scam hi nikla
# 10/7/23, 11:38 - Reshu Bhabhi: 😂😂
# 10/7/23, 11:38 - Reshu Bhabhi: Same here
# 10/7/23, 11:41 - Mona: 🤪🤪
# 10/21/23, 06:12 - Didi: <Media omitted>
# 11/10/23, 17:22 - Anil Jiju: Shubh Dhanteras to all! ✨
#
# May this day mark the beginning of a prosperous journey filled with health, wealth, and happiness.🙏
# 11/12/23, 07:52 - Anil Jiju: <Media omitted>
# 11/12/23, 14:58 - Bade Jiju: “May this Diwali fill your home with happiness, your heart with love, and your life with light. Wishing a joyous , prosperous and peaceful Diwali to you and dear family!"🌷💥🌷.🙏
# $ Sonika💗Kamleshwar Singh $
# 11/12/23, 19:14 - subSin: <Media omitted>
# 11/14/23, 11:14 - Didi: <Media omitted>
# 11/22/23, 09:21 - Bhaiya Jio: Happy anniversary didi and jija ji
# 11/22/23, 09:54 - Reshu Bhabhi: Happy anniversary didi and jijaji 💐💐
# 11/22/23, 10:07 - Mona: Happy marriage anniversary didi and jiju
# 11/22/23, 13:18 - Didi: Thanku bhaiya
# 11/22/23, 13:18 - Didi: Thanku bhabhi🙏❤️
# 11/22/23, 13:18 - Didi: Thanku mona
# 11/22/23, 13:47 - subSin: Happy anniversary jiju/ didi🥦🥦
# 11/22/23, 14:02 - Didi: Thanku dadu
# 11/22/23, 14:06 - subSin: To kya especial plan hai Aaj ka
# 11/22/23, 14:18 - Bade Jiju: Aap sabhi ko tahe 💗 se dhanyawad. Thanku so much 🙏🙏
# 11/22/23, 14:50 - Didi: Aj ka kaya plan hai ye to nhi btaye ji
# 11/22/23, 17:28 - Anil Jiju: Happy anniversary to both of you
# 11/22/23, 18:18 - Didi: Thanku Anil ji
# 11/25/23, 22:21 - Bhaiya Jio: https://youtube.com/shorts/3sHj8nwJsEs?si=VQ9jWDAvCDNtGI-3

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
message = re.split(pattern, data)[1:]

# %%
message
# Out:
# ['You created group "HAPPY family"\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Reshu Bhabhi: 👌🏻👌🏻\n',
#  'Mona: Great bhai bahan dono dancer ho gaye\n',
#  'Reshu Bhabhi: <Media omitted>\n',
#  'Reshu Bhabhi: Shanvi ka b same song hai\n',
#  'Anil Jiju: Jai shree krishna 🕉️🙏🙏\n',
#  'Bhaiya Jio: 👏👏👏👏\n',
#  'Bhaiya Jio: 👏👏👏👏\n',
#  'Mona: Shanvi ke liye v clapping👏👏👏\n',
#  'Mona: Happy birthday bhabhi 🥳🥳🥳\n',
#  'Didi: Wish u a very happy birthday dear bhabhi 🎂🎂🎂🎂🎂🍬🍬🍫🍫🍫🌹🌹🌹\n',
#  'Reshu Bhabhi: Thankyou mona 🙏🏻\n',
#  'Reshu Bhabhi: This message was deleted\n',
#  'Bade Jiju: Happy Birthday bhabhiji 🎂🎂\n',
#  'Reshu Bhabhi: Thankyou jijaji 🙏🏻\n',
#  'Mona: Bhabhi typing mistake 🤪\n',
#  'Reshu Bhabhi: 😄😄\n',
#  'Reshu Bhabhi: Thankyou didi 🙏🏻🙏🏻😄\n',
#  'Anil Jiju: <Media omitted>\n',
#  'Anil Jiju: Happy birthday 🎂🎂 🎈 Bhabhi ji.. enjoy your special day with lots of love and blessings.\n',
#  'Reshu Bhabhi: Thankyou jijaji 🙏🏻\n',
#  'Reshu Bhabhi: https://wintermedieval.top/nTiwpTTTT56d?xxyl1696653395155\n',
#  'Mona: https://thirteensquad.top/nTiwpTTTT218?ueuz1696657410648\n',
#  "Mona: It's a scam yaar\n",
#  'Mona: Sbko send kr diya socha tata hai sayad sahi ho bt ye v scam hi nikla\n',
#  'Reshu Bhabhi: 😂😂\n',
#  'Reshu Bhabhi: Same here\n',
#  'Mona: 🤪🤪\n',
#  'Didi: <Media omitted>\n',
#  'Anil Jiju: Shubh Dhanteras to all! ✨\n\nMay this day mark the beginning of a prosperous journey filled with health, wealth, and happiness.🙏\n',
#  'Anil Jiju: <Media omitted>\n',
#  'Bade Jiju: “May this Diwali fill your home with happiness, your heart with love, and your life with light. Wishing a joyous , prosperous and peaceful Diwali to you and dear family!"🌷💥🌷.🙏\n$ Sonika💗Kamleshwar Singh $\n',
#  'subSin: <Media omitted>\n',
#  'Didi: <Media omitted>\n',
#  'Bhaiya Jio: Happy anniversary didi and jija ji\n',
#  'Reshu Bhabhi: Happy anniversary didi and jijaji 💐💐\n',
#  'Mona: Happy marriage anniversary didi and jiju\n',
#  'Didi: Thanku bhaiya\n',
#  'Didi: Thanku bhabhi🙏❤️\n',
#  'Didi: Thanku mona\n',
#  'subSin: Happy anniversary jiju/ didi🥦🥦\n',
#  'Didi: Thanku dadu\n',
#  'subSin: To kya especial plan hai Aaj ka\n',
#  'Bade Jiju: Aap sabhi ko tahe 💗 se dhanyawad. Thanku so much 🙏🙏\n',
#  'Didi: Aj ka kaya plan hai ye to nhi btaye ji\n',
#  'Anil Jiju: Happy anniversary to both of you\n',
#  'Didi: Thanku Anil ji\n',
#  'Bhaiya Jio: https://youtube.com/shorts/3sHj8nwJsEs?si=VQ9jWDAvCDNtGI-3\n']

# %%
dates = re.findall(pattern, data)
dates
# Out:
# ['7/29/23, 08:47 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/5/23, 16:32 - ',
#  '9/7/23, 08:35 - ',
#  '9/7/23, 08:38 - ',
#  '9/7/23, 08:43 - ',
#  '9/7/23, 08:49 - ',
#  '9/7/23, 10:24 - ',
#  '9/7/23, 10:25 - ',
#  '9/7/23, 10:56 - ',
#  '9/7/23, 11:35 - ',
#  '9/7/23, 11:35 - ',
#  '9/7/23, 12:28 - ',
#  '9/8/23, 07:48 - ',
#  '9/8/23, 08:42 - ',
#  '9/8/23, 12:38 - ',
#  '9/8/23, 12:38 - ',
#  '9/8/23, 12:39 - ',
#  '9/8/23, 12:39 - ',
#  '9/8/23, 12:40 - ',
#  '9/8/23, 12:41 - ',
#  '9/8/23, 12:41 - ',
#  '9/8/23, 17:20 - ',
#  '9/8/23, 17:21 - ',
#  '9/8/23, 19:11 - ',
#  '10/7/23, 10:07 - ',
#  '10/7/23, 11:13 - ',
#  '10/7/23, 11:29 - ',
#  '10/7/23, 11:30 - ',
#  '10/7/23, 11:38 - ',
#  '10/7/23, 11:38 - ',
#  '10/7/23, 11:41 - ',
#  '10/21/23, 06:12 - ',
#  '11/10/23, 17:22 - ',
#  '11/12/23, 07:52 - ',
#  '11/12/23, 14:58 - ',
#  '11/12/23, 19:14 - ',
#  '11/14/23, 11:14 - ',
#  '11/22/23, 09:21 - ',
#  '11/22/23, 09:54 - ',
#  '11/22/23, 10:07 - ',
#  '11/22/23, 13:18 - ',
#  '11/22/23, 13:18 - ',
#  '11/22/23, 13:18 - ',
#  '11/22/23, 13:47 - ',
#  '11/22/23, 14:02 - ',
#  '11/22/23, 14:06 - ',
#  '11/22/23, 14:18 - ',
#  '11/22/23, 14:50 - ',
#  '11/22/23, 17:28 - ',
#  '11/22/23, 18:18 - ',
#  '11/25/23, 22:21 - ']

# %%
df = pd.DataFrame({'user_message':message, 'message_date':dates})
df['message_date'] = pd.to_datetime(df['message_date'],format = '%m/%d/%y, %H:%M - ')
df.rename(columns={'message_date':'date'}, inplace=True)
df.sample(5)
# Out:
#                 user_message                date
# 13   Didi: <Media omitted>\n 2023-09-07 08:35:00
# 20        Bhaiya Jio: 👏👏👏👏\n 2023-09-07 11:35:00
# 37  Mona: It's a scam yaar\n 2023-10-07 11:29:00
# 10   Didi: <Media omitted>\n 2023-09-05 16:32:00
# 53       Didi: Thanku mona\n 2023-11-22 13:18:00

# %%
df.shape
# Out:
# (62, 2)

# %%
# separating user and message
users = []
messages = []
for message in df['user_message']:
  entry = re.split('([\w\W]+?):\s', message)
  if entry[1:]:
    users.append(entry[1])
    messages.append(entry[2])
  else:
    users.append('group_notification')
    messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)
df.sample(5)
# Out:
#                   date       user                             message
# 11 2023-09-05 16:32:00       Didi                   <Media omitted>\n
# 10 2023-09-05 16:32:00       Didi                   <Media omitted>\n
# 4  2023-09-05 16:32:00       Didi                   <Media omitted>\n
# 6  2023-09-05 16:32:00       Didi                   <Media omitted>\n
# 59 2023-11-22 17:28:00  Anil Jiju  Happy anniversary to both of you\n

# %%
df['year']=df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user                             message  \
# 0 2023-07-29 08:47:00  group_notification  You created group "HAPPY family"\n
# 1 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 2 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 3 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 4 2023-09-05 16:32:00                Didi                   <Media omitted>\n
#
#    year
# 0  2023
# 1  2023
# 2  2023
# 3  2023
# 4  2023

# %%
df['month']=df['date'].dt.month_name()

# %%
df['day']=df['date'].dt.day
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user                             message  \
# 0 2023-07-29 08:47:00  group_notification  You created group "HAPPY family"\n
# 1 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 2 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 3 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 4 2023-09-05 16:32:00                Didi                   <Media omitted>\n
#
#    year      month  day  hour  minute
# 0  2023       July   29     8      47
# 1  2023  September    5    16      32
# 2  2023  September    5    16      32
# 3  2023  September    5    16      32
# 4  2023  September    5    16      32

# %%
df.shape[0]
# Out:
# 62

# %%
words = []
for word in df['message']:
  words.extend(message.split())

# %%
len(words)
# Out:
# 186

# %%
# top 5 user
x=df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x=x.index, height=x.values )
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Didi'),
#   Text(1, 0, 'Reshu Bhabhi'),
#   Text(2, 0, 'Mona'),
#   Text(3, 0, 'Anil Jiju'),
#   Text(4, 0, 'Bhaiya Jio')])

# %%
# percentage of user messages
df = round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns = {'index':'name','user':'percentage'})
# Out:
#                  name  percentage
# 0                Didi       37.10
# 1        Reshu Bhabhi       20.97
# 2                Mona       14.52
# 3           Anil Jiju        9.68
# 4          Bhaiya Jio        6.45
# 5           Bade Jiju        4.84
# 6              subSin        4.84
# 7  group_notification        1.61

# %%
# top 20 words in chat
words = []
for word in temp['message']:
  words.extend(word.split())

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#               0  1
# 0         Happy  8
# 1           and  8
# 2        Thanku  6
# 3          with  5
# 4   anniversary  5
# 5           hai  4
# 6             a  4
# 7      Thankyou  4
# 8          didi  4
# 9          your  4
# 10           to  4
# 11           ka  3
# 12     birthday  3
# 13           🙏🏻  3
# 14       jijaji  3
# 15           of  3
# 16           ji  3
# 17           ho  2
# 18       Shanvi  2
# 19         👏👏👏👏  2

# %%
# we need to do preprocessing
# 1. remove group messages
# 2. remove media ommited

# %%
temp = df[df['message'] != 'group_notification']
temp = temp[temp['message'] != '<Media omitted>\n']

# %%
df
# Out:
#                   date                user  \
# 0  2023-07-29 08:47:00  group_notification
# 1  2023-09-05 16:32:00                Didi
# 2  2023-09-05 16:32:00                Didi
# 3  2023-09-05 16:32:00                Didi
# 4  2023-09-05 16:32:00                Didi
# ..                 ...                 ...
# 57 2023-11-22 14:18:00           Bade Jiju
# 58 2023-11-22 14:50:00                Didi
# 59 2023-11-22 17:28:00           Anil Jiju
# 60 2023-11-22 18:18:00                Didi
# 61 2023-11-25 22:21:00          Bhaiya Jio
#
#                                               message  year      month  day  \
# 0                  You created group "HAPPY family"\n  2023       July   29
# 1                                   <Media omitted>\n  2023  September    5
# 2                                   <Media omitted>\n  2023  September    5
# 3                                   <Media omitted>\n  2023  September    5
# 4                                   <Media omitted>\n  2023  September    5
# ..                                                ...   ...        ...  ...
# 57  Aap sabhi ko tahe 💗 se dhanyawad. Thanku so mu...  2023   November   22
# 58           Aj ka kaya plan hai ye to nhi btaye ji\n  2023   November   22
# 59                 Happy anniversary to both of you\n  2023   November   22
# 60                                   Thanku Anil ji\n  2023   November   22
# 61  https://youtube.com/shorts/3sHj8nwJsEs?si=VQ9j...  2023   November   25
#
#     hour  minute
# 0      8      47
# 1     16      32
# 2     16      32
# 3     16      32
# 4     16      32
# ..   ...     ...
# 57    14      18
# 58    14      50
# 59    17      28
# 60    18      18
# 61    22      21
#
# [62 rows x 8 columns]

# %%
# time based analysis
df['month_num'] = df['date'].dt.month

# %%
df.head()
# Out:
#                  date                user                             message  \
# 0 2023-07-29 08:47:00  group_notification  You created group "HAPPY family"\n
# 1 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 2 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 3 2023-09-05 16:32:00                Didi                   <Media omitted>\n
# 4 2023-09-05 16:32:00                Didi                   <Media omitted>\n
#
#    year      month  day  hour  minute  month_number
# 0  2023       July   29     8      47             7
# 1  2023  September    5    16      32             9
# 2  2023  September    5    16      32             9
# 3  2023  September    5    16      32             9
# 4  2023  September    5    16      32             9

# %%
timeline = df.groupby(['year', 'month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#    year  month_num      month  message
# 0  2023          7       July        1
# 1  2023          9  September       34
# 2  2023         10    October        8
# 3  2023         11   November       19

# %%
time = []
for i in range(timeline.shape[0]):
  time.append(timeline['month'][i]+"-"+str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#    year  month_num      month  message            time
# 0  2023          7       July        1       July-2023
# 1  2023          9  September       34  September-2023
# 2  2023         10    October        8    October-2023
# 3  2023         11   November       19   November-2023

# %%
plt.plot(timeline['time'], timeline['message'])
